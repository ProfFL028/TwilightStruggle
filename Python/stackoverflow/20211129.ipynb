# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
# %matplotlib qt5
R=3.844e8
T=0.5
k=3.959e14
dθ,dt=0.1,0.001
rx,ry=0,-R
vx,vy=R*dθ/dt,0
'''for i in range(0,int(T/dt)):
    ax=-k/((rx[i]**2+ry[i]**2)**1.5)*rx[i]
    ay=-k/((rx[i]**2+ry[i]**2)**1.5)*ry[i]
    vx+=ax*dt
    vy+=ay*dt
    rx.append(rx[i]+vx*dt)
    ry.append(ry[i]+vy*dt)
'''
fig,ax=plt.subplots()
ax.set_xlim(0,1e8)
ax.set_ylim(-1e9,1e9)
x,y=[],[]
line,=plt.plot([],[],'bo')
# def update(i):
#     global vx,vy,rx,ry
#     ax=-k/((rx**2+ry**2)**1.5)*rx
#     ay=-k/((rx**2+ry**2)**1.5)*ry
#     vx+=ax*dt
#     vy+=ay*dt
#     rx+=vx*dt
#     ry+=vy*dt
#     x.append(rx)
#     y.append(ry)
#     line.set_data(rx,ry)
#     return line,
# ani=FuncAnimation(fig,update,frames=range(0,int(T/dt)))
# plt.show()

for i in range(0, int(T/dt)):
    ax=-k/((rx**2+ry**2)**1.5)*rx
    ay=-k/((rx**2+ry**2)**1.5)*ry
    vx+=ax*dt
    vy+=ay*dt
    rx+=vx*dt
    ry+=vy*dt
    x.append(rx)
    y.append(ry)
    print(rx, ry)
# Out:
# 38440000.0 -384400000.0
# 76880000.0 -384400000.0
# 115320000.0 -384400000.0
# 153760000.0 -384400000.0
# 192200000.0 -384400000.0
# 230640000.0 -384400000.0
# 269080000.0 -384400000.0
# 307520000.0 -384400000.0
# 345960000.0 -384400000.0
# 384400000.0 -384400000.0
# 422840000.0 -384400000.0
# 461280000.0 -384400000.0
# 499720000.0 -384400000.0
# 538160000.0 -384400000.0
# 576600000.0 -384400000.0
# 615040000.0 -384400000.0
# 653480000.0 -384400000.0
# 691920000.0 -384400000.0
# 730360000.0 -384400000.0
# 768800000.0 -384400000.0
# 807240000.0 -384400000.0
# 845680000.0 -384400000.0
# 884120000.0 -384400000.0
# 922560000.0 -384400000.0
# 961000000.0 -384400000.0
# 999440000.0 -384400000.0
# 1037880000.0 -384400000.0
# 1076320000.0 -384400000.0
# 1114760000.0 -384400000.0
# 1153200000.0 -384400000.0
# 1191640000.0 -384400000.0
# 1230080000.0 -384400000.0
# 1268520000.0 -384400000.0
# 1306960000.0 -384400000.0
# 1345400000.0 -384400000.0
# 1383840000.0 -384400000.0
# ...
