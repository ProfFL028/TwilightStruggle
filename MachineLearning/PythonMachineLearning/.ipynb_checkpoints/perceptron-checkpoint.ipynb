# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import numpy as np

# %%
data = load_iris()
X = data.data
y = data.target

# %%
plt.scatter(X[:50, 0], X[:50, 1], color='red', marker='o', label='setosa')
plt.scatter(X[50:, 0], X[50:, 1], color='blue', marker='x', label='versicolor')
plt.xlabel('sepal length (cm)')
plt.ylabel('petal length (cm)')
plt.legend(loc='upper left')
plt.show()

# %%
ppn = Perceptron(eta=0.1, n_iter=10)
ppn.fit(X, y)
plt.plot(range(1, len(ppn.errors_)+1), ppn.errors_, marker='o')
plt.xlabel('Epochs')
plt.ylabel('Number of updates')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-46d02c5e4d51> in <module>
#       1 from Perceptron import Perceptron
#       2 ppn = Perceptron(eta=0.1, n_iter=10)
# ----> 3 ppn.fit(X, y)
#       4 plt.plot(range(1, len(ppn.errors_)+1), ppn.errors_, marker='o')
#       5 plt.xlabel('Epochs')
#
# E:\TwilightStruggle\MachineLearning\PythonMachineLearning\Perceptron.py in fit(self, X, y)
#      19
#      20     def fit(self, X, y):
# ---> 21         self.errors_ = []
#      22         for _ in range(self.n_iter):
#      23             errors = 0
#
# E:\TwilightStruggle\MachineLearning\PythonMachineLearning\Perceptron.py in predict(self, X)
#      30         return self
#      31
# ---> 32     def net_input(self, X):
#      33         return np.dot(X, self.w_[1:]) + self.w_[0]
#      34
#
# E:\TwilightStruggle\MachineLearning\PythonMachineLearning\Perceptron.py in net_input(self, X)
#      27                 self.w_[0] += update
#      28                 errors += int(update != 0.0)
# ---> 29             self.errors_.append(errors)
#      30         return self
#      31
#
# AttributeError: 'Perceptron' object has no attribute 'w_'
