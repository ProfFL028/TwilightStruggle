# %%
import tensorflow as tf
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = tf.reshape(train_images, (train_images.shape[0], train_images.shape[1], train_images.shape[2], 1))
test_images = tf.reshape(test_images, (test_images.shape[0], test_images.shape[1], test_images.shape[2], 1))
print("train_images.shape modified:", train_images.shape)
# Out:
# train_images.shape modified: (60000, 28, 28, 1)

# %%
lenet5 = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters=6, kernel_size=(5, 5), activation="sigmoid", input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPool2D(pool_size=(2, 2), strides=2),
    tf.keras.layers.Conv2D(filters=16, kernel_size=(5, 5), activation="sigmoid", padding="same"),
    tf.keras.layers.MaxPool2D(pool_size=(2, 2), strides=2),
    tf.keras.layers.Conv2D(filters=32, kernel_size=(5, 5), activation="sigmoid", padding="same"),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(200, activation="sigmoid"),
    tf.keras.layers.Dense(10, activation="sigmoid")
])

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.9, momentum=0.0, nesterov=False)
lenet5.compile(optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=['accuracy'])
lenet5.fit(train_images, train_labels, epochs=5, validation_split=0.2)

scores = lenet5.evaluate(test_images, test_labels, verbose=1)
print(scores)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 19s 12ms/step - loss: 2.3199 - accuracy: 0.1042 - val_loss: 2.3150 - val_accuracy: 0.0997
# Epoch 2/5
# 1500/1500 [==============================] - 19s 12ms/step - loss: 2.3069 - accuracy: 0.1112 - val_loss: 2.2799 - val_accuracy: 0.1996
# Epoch 3/5
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.4522 - accuracy: 0.8411 - val_loss: 0.1255 - val_accuracy: 0.9617
# Epoch 4/5
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.1145 - accuracy: 0.9629 - val_loss: 0.0798 - val_accuracy: 0.9753
# Epoch 5/5
# 1500/1500 [==============================] - 18s 12ms/step - loss: 0.1045 - accuracy: 0.9663 - val_loss: 0.0859 - val_accuracy: 0.9737
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0769 - accuracy: 0.9758
# [0.07689864188432693, 0.9757999777793884]
